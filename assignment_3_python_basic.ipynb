# %% [markdown]
# 1.	Why are functions advantageous to have in your programs?
#
# Functions give reusability to the the code i.e. we can use same code for different input values.
#
# 2.	When does the code in a function run: when it's specified or when it's called?
#
# While calling the function
#
# 3. What statement creates a function?
#
# def function_name(argument if any):
# 	operation
# 	return
# 4. What is the difference between a function and a function call?
#
# Function is a set of codes for specific problem statement and function call means we are calling that function to meet the requirement.
#
# 5. How many global scopes are there in a Python program? How many local scopes?
#
# Global scopes are those variable which are assigned globally which means they have the same value throughout that file.
# Local variable are assigned within the user defined function. So they have that value within that function only.
#
# 6. What happens to variables in a local scope when the function call returns?
#
# Return keyword in function yields the value of that variable.
#
# 7. What is the concept of a return value? Is it possible to have a return value in an expression?
#
# Return keyword in function yields the value of the function. Yes we can have return value expression.
#
# 8. If a function does not have a return statement, what is the return value of a call to that function?
#
# That function will not return any value.
#
# 9. How do you make a function variable refer to the global variable?
#
# We have to use global keyword with the local variable.
#
# 10. What is the data type of None?
#
# We cannot apply any operation on none datatype output.
#
# 11. What does the sentence import areallyourpetsnamederic do?
#
# It will import class areallyourpetsnamederic if exists.
#
# 12. If you had a bacon() feature in a spam module, what would you call it after importing spam?
#
# Obj = spam.bacon()
#
# 13. What can you do to save a programme from crashing if it encounters an error?
#
# We can use exception handling technique.
#
# 14. What is the purpose of the try clause? What is the purpose of the except clause?
#
# Try keyword means we want to test this code and except keyword means we want to exclude that type of error if it appears.
